# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [raw]
# !pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
    return url_link.split("watch?v=")[-1]

# %%
video_id = get_video_id("https://www.youtube.com/watch?v=uHEPBzYick0")

# %%
video_id
# Out:
# 'uHEPBzYick0'

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': "- Apple's done a fantastic\njob of really innovating",
#   'start': 0.21,
#   'duration': 3.3},
#  {'text': 'on the Mac, we are gonna outperform them.',
#   'start': 3.51,
#   'duration': 3.0},
#  {'text': "- So you feel like you've got Apple now.",
#   'start': 6.51,
#   'duration': 1.59},
#  {'text': '- We have a computer for\npeople who love Windows',
#   'start': 8.1,
#   'duration': 3.51},
#  {'text': 'that they can be very, very proud of.',
#   'start': 11.61,
#   'duration': 1.5},
#  {'text': '- Microsoft, CEO Satya Nadella', 'start': 13.11, 'duration': 2.01},
#  {'text': 'is very excited about\nhis new Windows computers',
#   'start': 15.12,
#   'duration': 3.15},
#  {'text': "because they're not just\nany Windows computers.",
#   'start': 18.27,
#   'duration': 2.97},
#  {'text': "Can we call 'em AI-puters?", 'start': 21.24, 'duration': 2.601},
#  {'text': '- (laughs) No, I like Copilot+PC.',
#   'start': 23.841,
#   'duration': 2.109},
# ...

# %%
transcript_joined=" ".join([line['text'] for line in transcript])

# %%
transcript_joined
# Out:
# '- Apple\'s done a fantastic\njob of really innovating on the Mac, we are gonna outperform them. - So you feel like you\'ve got Apple now. - We have a computer for\npeople who love Windows that they can be very, very proud of. - Microsoft, CEO Satya Nadella is very excited about\nhis new Windows computers because they\'re not just\nany Windows computers. Can we call \'em AI-puters? - (laughs) No, I like Copilot+PC. - [Joanna] Yes, these Copilot+PCs coming from Microsoft itself and others like Lenovo and Dell have been completely re-engineered for. - AI, AI, AI, AI, AI as a new input. - But what even is an AI computer? Microsoft\'s latest have\nnew chips and AI software that can do some cool tricks without even needing to\nconnect to the internet. After talking to Nadella and seeing the new\nSurface devices in action, I\'ll say it looks pretty darn promising. - Here\'s the interesting thing, right? Which is, if you sort of take all of what we\'ve been talking about with AI, it all cam
# ...

# %%
# !pip install rpunct
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 42.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.7 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# INFO: pip is looking at multiple versions of rpunct to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1 (from rpunct) (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.8.1

# %%
# !pip install deepmultilingualpunctuation

# %%
from deepmultilingualpunctuation import PunctuationModel

# %%
model = PunctuationModel()
result = model.restore_punctuation(transcript_joined)
# Out:
# config.json:   0%|          | 0.00/892 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/406 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
print(transcript_joined)
# Out:
# - Apple's done a fantastic
# job of really innovating on the Mac, we are gonna outperform them. - So you feel like you've got Apple now. - We have a computer for
# people who love Windows that they can be very, very proud of. - Microsoft, CEO Satya Nadella is very excited about
# his new Windows computers because they're not just
# any Windows computers. Can we call 'em AI-puters? - (laughs) No, I like Copilot+PC. - [Joanna] Yes, these Copilot+PCs coming from Microsoft itself and others like Lenovo and Dell have been completely re-engineered for. - AI, AI, AI, AI, AI as a new input. - But what even is an AI computer? Microsoft's latest have
# new chips and AI software that can do some cool tricks without even needing to
# connect to the internet. After talking to Nadella and seeing the new
# ...

# %%
print(result)
# Out:
# - Apple's done a fantastic job of really innovating on the Mac. we are gonna outperform them - So you feel like you've got Apple now. - We have a computer for people who love Windows that they can be very, very proud of. - Microsoft CEO Satya Nadella is very excited about his new Windows computers, because they're not just any Windows computers. Can we call 'em AI-puters? - (laughs) No, I like Copilot+PC. - [Joanna] Yes, these Copilot+PCs coming from Microsoft itself and others like Lenovo and Dell, have been completely re-engineered for - AI, AI, AI, AI, AI as a new input. - But what even is an AI computer? Microsoft's latest have new chips and AI software that can do some cool tricks without even needing to connect to the internet. After talking to Nadella and seeing the new Surface devices in action, I'll say it looks pretty darn promising. - Here's the interesting thing, right, Which is, if you sort of take all of what we've been talking about with AI, it all came about because o
# ...

# %%
prompt=f'"Summarize this text: \n text="{result}"'

# %%
# !pip install groq
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import os

# Set the environment variable
os.environ["GROQ_API_KEY"] = "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"

# Verify it's set

print(os.environ.get("GROQ_API_KEY"))
# Out:
# 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

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=True,
    stop=None,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# The text is an interview between Joanna and an unnamed Microsoft executive, discussing Microsoft's new Copilot+PCs, which are designed to integrate artificial intelligence (AI) into the Windows operating system. The executive highlights the innovative features of these new computers, such as:
#
# 1. AI-processed graphics and images: The Copilot+PCs can generate photorealistic images and graphics without needing to connect to the internet.
# 2. Edge computing: The NPU (Neural Processing Unit) join the CPU and GPU, enabling local processing of AI tasks.
# 3. Recall: A new AI-powered search feature that can recreate moments from the past and recall specific information.
# 4. Co-creator: An AI-powered drawing tool that allows users to co-create with an AI model.
#
# ...
